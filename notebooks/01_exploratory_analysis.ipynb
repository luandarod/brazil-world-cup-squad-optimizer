# %% [markdown]
# # Brazil World Cup Squad Optimizer
#
# Análise exploratória inicial dos dados de jogadores brasileiros.

# %%
import pandas as pd
df = pd.read_csv('../data/processed/sample_brazil_players.csv')
df.head()
